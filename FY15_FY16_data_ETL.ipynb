# %%
import pandas as pd
import numpy as np

# %%
fy15_data_path = "Resources/FY15_data.xlsx"
fy15_df = pd.read_excel(fy15_data_path)
fy15_df.head()
# Out:
#      CASE_NUMBER DECISION_DATE        CASE_STATUS CASE_RECEIVED_DATE REFILE  \
# 0  A-14220-96665    2015-02-03  Certified-Expired         2014-09-10      N
# 1  A-14220-96720    2015-01-12  Certified-Expired         2014-08-08      N
# 2  A-14203-91167    2014-12-18  Certified-Expired         2014-07-28      N
# 3  A-14206-92509    2015-03-10  Certified-Expired         2014-10-19      N
# 4  A-14202-90786    2015-01-07  Certified-Expired         2014-08-25      N
#
#   ORIG_FILE_DATE ORIG_CASE_NO SCHD_A_SHEEPHERDER               EMPLOYER_NAME  \
# 0            NaT          NaN                  N      UNION PACIFIC RAILROAD
# 1            NaT          NaN                  N          VST CONSULTING INC
# 2            NaT          NaN                  N                 GOOGLE INC.
# 3            NaT          NaN                  N           INTEL CORPORATION
# 4            NaT          NaN                  N  NET ESOLUTIONS CORPORATION
#
#                 EMPLOYER_ADDRESS_1                   ...                    \
# 0  1400 DOUGLAS ST, STOP CODE 0320                   ...
# 1          200 MIDDLESEX ESSEX TPK                   ...
# 2        1600 AMPHITHEATRE PARKWAY                   ...
# 3       2200 MISSION COLLEGE BLVD.                   ...
# 4            8280 GREENSBORO DRIVE                   ...
#
#   FW_INFO_TRAINING_COMP FW_INFO_REQ_EXPERIENCE FW_INFO_ALT_EDU_EXPERIENCE  \
# 0                     A                      Y                          Y
# 1                     A                      Y                          A
# 2                     A                      A                          N
# 3                     A                      A                          A
# 4                     A                      N                          Y
#
#   FW_INFO_REL_OCCUP_EXP PREPARER_INFO_EMP_COMPLETED PREPARER_INFO_TITLE  \
# 0                     A                           N     Attorney at Law
# 1                     Y                           N            ATTORNEY
# 2                     Y                           N            Attorney
# 3                     A                           N            Attorney
# 4                     Y                           N     Attorney-at-Law
#
#                     EMPLOYER_DECL_INFO_TITLE  NAICS_US_CODE  \
# 0  Assistant Vice President, Human Resources         482111
# 1                                  PRESIDENT         541511
# 2             Immigration Program Specialist         541512
# 3               U.S. Immigration Ops Manager           3344
# 4                          Managing Director         541511
#
#                                       NAICS_US_TITLE  \
# 0                                Line-Haul Railroads
# 1               Custom Computer Programming Services
# 2                   Computer Systems Design Services
# 3  Semiconductor and Other Electronic Component M...
# 4               Custom Computer Programming Services
#
#                         PW_Job_Title_9089
# 0       Software Developers, Applications
# 1       Software Developers, Applications
# 2       Software Developers, Applications
# 3  Electronics Engineers, Except Computer
# 4       Software Developers, Applications
#
# [5 rows x 125 columns]

# %%
fy15_df.columns
# Out:
# Index(['CASE_NUMBER', 'DECISION_DATE', 'CASE_STATUS', 'CASE_RECEIVED_DATE',
#        'REFILE', 'ORIG_FILE_DATE', 'ORIG_CASE_NO', 'SCHD_A_SHEEPHERDER',
#        'EMPLOYER_NAME', 'EMPLOYER_ADDRESS_1',
#        ...
#        'FW_INFO_TRAINING_COMP', 'FW_INFO_REQ_EXPERIENCE',
#        'FW_INFO_ALT_EDU_EXPERIENCE', 'FW_INFO_REL_OCCUP_EXP',
#        'PREPARER_INFO_EMP_COMPLETED', 'PREPARER_INFO_TITLE',
#        'EMPLOYER_DECL_INFO_TITLE', 'NAICS_US_CODE', 'NAICS_US_TITLE',
#        'PW_Job_Title_9089'],
#       dtype='object', length=125)

# %%
# Select the columns that we need
fy15_df2 = fy15_df[['CASE_NUMBER','DECISION_DATE','CASE_STATUS','CASE_RECEIVED_DATE','EMPLOYER_NAME','EMPLOYER_CITY',
                   'EMPLOYER_STATE','EMPLOYER_POSTAL_CODE','EMPLOYER_NUM_EMPLOYEES','AGENT_FIRM_NAME','AGENT_CITY',
                   'AGENT_STATE','PW_SOC_CODE','PW_SOC_TITLE','PW_AMOUNT_9089','WAGE_OFFER_FROM_9089','WAGE_OFFER_UNIT_OF_PAY_9089',
                   'JOB_INFO_WORK_CITY','JOB_INFO_WORK_STATE','JOB_INFO_WORK_POSTAL_CODE','JOB_INFO_JOB_TITLE',
                   'JOB_INFO_EDUCATION','JOB_INFO_EDUCATION_OTHER','FOREIGN_WORKER_INFO_CITY','FOREIGN_WORKER_INFO_STATE',
                   'FW_INFO_POSTAL_CODE','COUNTRY_OF_CITIZENSHIP','FW_INFO_BIRTH_COUNTRY','CLASS_OF_ADMISSION','FOREIGN_WORKER_INFO_EDUCATION','FW_INFO_EDUCATION_OTHER']]
fy15_df2.dtypes
# Out:
# CASE_NUMBER                              object
# DECISION_DATE                    datetime64[ns]
# CASE_STATUS                              object
# CASE_RECEIVED_DATE               datetime64[ns]
# EMPLOYER_NAME                            object
# EMPLOYER_CITY                            object
# EMPLOYER_STATE                           object
# EMPLOYER_POSTAL_CODE                     object
# EMPLOYER_NUM_EMPLOYEES                  float64
# AGENT_FIRM_NAME                          object
# AGENT_CITY                               object
# AGENT_STATE                              object
# PW_SOC_CODE                              object
# PW_SOC_TITLE                             object
# PW_AMOUNT_9089                          float64
# WAGE_OFFER_FROM_9089                    float64
# WAGE_OFFER_UNIT_OF_PAY_9089              object
# JOB_INFO_WORK_CITY                       object
# JOB_INFO_WORK_STATE                      object
# JOB_INFO_WORK_POSTAL_CODE                object
# JOB_INFO_JOB_TITLE                       object
# JOB_INFO_EDUCATION                       object
# JOB_INFO_EDUCATION_OTHER                 object
# FOREIGN_WORKER_INFO_CITY                 object
# FOREIGN_WORKER_INFO_STATE                object
# FW_INFO_POSTAL_CODE                      object
# COUNTRY_OF_CITIZENSHIP                   object
# FW_INFO_BIRTH_COUNTRY                    object
# CLASS_OF_ADMISSION                       object
# FOREIGN_WORKER_INFO_EDUCATION            object
# FW_INFO_EDUCATION_OTHER                  object
# dtype: object

# %%
# change column to float
fy15_df2['WAGE_OFFER_FROM_9089'] = fy15_df2['WAGE_OFFER_FROM_9089'].astype(float)
fy15_df2.dtypes
# Out:
# C:\Users\freguenet3\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# CASE_NUMBER                              object
# DECISION_DATE                    datetime64[ns]
# CASE_STATUS                              object
# CASE_RECEIVED_DATE               datetime64[ns]
# EMPLOYER_NAME                            object
# EMPLOYER_CITY                            object
# EMPLOYER_STATE                           object
# EMPLOYER_POSTAL_CODE                     object
# EMPLOYER_NUM_EMPLOYEES                  float64
# AGENT_FIRM_NAME                          object
# AGENT_CITY                               object
# AGENT_STATE                              object
# PW_SOC_CODE                              object
# PW_SOC_TITLE                             object
# PW_AMOUNT_9089                          float64
# WAGE_OFFER_FROM_9089                    float64
# WAGE_OFFER_UNIT_OF_PAY_9089              object
# JOB_INFO_WORK_CITY                       object
# JOB_INFO_WORK_STATE                      object
# JOB_INFO_WORK_POSTAL_CODE                object
# JOB_INFO_JOB_TITLE                       object
# JOB_INFO_EDUCATION                       object
# JOB_INFO_EDUCATION_OTHER                 object
# FOREIGN_WORKER_INFO_CITY                 object
# FOREIGN_WORKER_INFO_STATE                object
# FW_INFO_POSTAL_CODE                      object
# COUNTRY_OF_CITIZENSHIP                   object
# FW_INFO_BIRTH_COUNTRY                    object
# CLASS_OF_ADMISSION                       object
# FOREIGN_WORKER_INFO_EDUCATION            object
# FW_INFO_EDUCATION_OTHER                  object
# dtype: object

# %%
fy15_df2.count()
# Out:
# CASE_NUMBER                      89297
# DECISION_DATE                    89297
# CASE_STATUS                      89297
# CASE_RECEIVED_DATE               89295
# EMPLOYER_NAME                    89293
# EMPLOYER_CITY                    89293
# EMPLOYER_STATE                   89284
# EMPLOYER_POSTAL_CODE             89289
# EMPLOYER_NUM_EMPLOYEES           89250
# AGENT_FIRM_NAME                  74050
# AGENT_CITY                       75869
# AGENT_STATE                      74725
# PW_SOC_CODE                      89141
# PW_SOC_TITLE                     89141
# PW_AMOUNT_9089                   89243
# WAGE_OFFER_FROM_9089             89262
# WAGE_OFFER_UNIT_OF_PAY_9089      88095
# JOB_INFO_WORK_CITY               89270
# JOB_INFO_WORK_STATE              89270
# JOB_INFO_WORK_POSTAL_CODE        89252
# JOB_INFO_JOB_TITLE               89274
# JOB_INFO_EDUCATION               89292
# JOB_INFO_EDUCATION_OTHER          2926
# FOREIGN_WORKER_INFO_CITY         88984
# FOREIGN_WORKER_INFO_STATE        84213
# FW_INFO_POSTAL_CODE              86241
# COUNTRY_OF_CITIZENSHIP           89273
# FW_INFO_BIRTH_COUNTRY            88980
# CLASS_OF_ADMISSION               83844
# FOREIGN_WORKER_INFO_EDUCATION    88979
# FW_INFO_EDUCATION_OTHER           3952
# dtype: int64

# %%
fy16_data_path = "Resources/FY16_data.xlsx"
fy16_df = pd.read_excel(fy16_data_path)
fy16_df.head()
# Out:
#      CASE_NUMBER DECISION_DATE        CASE_STATUS CASE_RECEIVED_DATE REFILE  \
# 0  A-15096-64168    2015-10-01          Withdrawn         2015-05-05      N
# 1  A-15273-23908    2015-10-01          Withdrawn         2015-10-01      N
# 2  A-15063-55943    2015-10-01  Certified-Expired         2015-03-10    NaN
# 3  A-15258-17757    2015-10-01          Withdrawn         2015-10-01      N
# 4  A-14212-94282    2015-10-01  Certified-Expired         2014-07-31    NaN
#
#   ORIG_FILE_DATE ORIG_CASE_NO SCHD_A_SHEEPHERDER  \
# 0            NaT          NaN                  N
# 1            NaT          NaN                  N
# 2            NaT          NaN                  N
# 3            NaT          NaN                  N
# 4            NaT          NaN                  N
#
#                            EMPLOYER_NAME         EMPLOYER_ADDRESS_1  \
# 0                Think Primary Care, LLC            7101 Mercy Road
# 1      Shopping & Shopping of Miami Corp          102 SE 1st Street
# 2                   TEXAS BACK INSTITUTE        6020 WEST PARKER RD
# 3  SARASOTA LAKEWOOD RANCH VENTURES, LLC  8210 LAKEWOOD RANCH BLVD.
# 4               NATIONS INFO CORPORATION        5951 ENCINA RD #208
#
#                          ...                         FW_INFO_TRAINING_COMP  \
# 0                        ...                                             A
# 1                        ...                                             A
# 2                        ...                                             A
# 3                        ...                                             A
# 4                        ...                                             A
#
#   FW_INFO_REQ_EXPERIENCE FW_INFO_ALT_EDU_EXPERIENCE FW_INFO_REL_OCCUP_EXP  \
# 0                      Y                          A                     A
# 1                      Y                          A                     A
# 2                      Y                          A                     Y
# 3                      Y                          A                     A
# 4                      A                          A                     A
#
#   PREPARER_INFO_EMP_COMPLETED PREPARER_INFO_TITLE    EMPLOYER_DECL_INFO_TITLE  \
# 0                           N            Attorney     Chief Financial Officer
# 1                           N           President                   President
# 2                           N            Attorney                 Director HR
# 3                           N            Attorney  Operating Principal/Broker
# 4                           N            Attorney     Human Resources Manager
#
#    NAICS_US_CODE                          NAICS_US_TITLE  \
# 0         621498       All Other Outpatient Care Centers
# 1         451110                   Sporting Goods Stores
# 2         622110  General Medical and Surgical Hospitals
# 3          53131           Real Estate Property Managers
# 4         516110    Internet Publishing and Broadcasting
#
#                                    PW_Job_Title_9089
# 0                                    Chief Executive
# 1                                            Manager
# 2                    General and Operations Managers
# 3  Market Research Analysts and Marketing Special...
# 4                                 Marketing Managers
#
# [5 rows x 125 columns]

# %%
fy16_df.columns
# Out:
# Index(['CASE_NUMBER', 'DECISION_DATE', 'CASE_STATUS', 'CASE_RECEIVED_DATE',
#        'REFILE', 'ORIG_FILE_DATE', 'ORIG_CASE_NO', 'SCHD_A_SHEEPHERDER',
#        'EMPLOYER_NAME', 'EMPLOYER_ADDRESS_1',
#        ...
#        'FW_INFO_TRAINING_COMP', 'FW_INFO_REQ_EXPERIENCE',
#        'FW_INFO_ALT_EDU_EXPERIENCE', 'FW_INFO_REL_OCCUP_EXP',
#        'PREPARER_INFO_EMP_COMPLETED', 'PREPARER_INFO_TITLE',
#        'EMPLOYER_DECL_INFO_TITLE', 'NAICS_US_CODE', 'NAICS_US_TITLE',
#        'PW_Job_Title_9089'],
#       dtype='object', length=125)

# %%
# Select the columns that we need
fy16_df2 = fy16_df[['CASE_NUMBER','DECISION_DATE','CASE_STATUS','CASE_RECEIVED_DATE','EMPLOYER_NAME','EMPLOYER_CITY',
                   'EMPLOYER_STATE','EMPLOYER_POSTAL_CODE','EMPLOYER_NUM_EMPLOYEES','AGENT_FIRM_NAME','AGENT_CITY',
                   'AGENT_STATE','PW_SOC_CODE','PW_SOC_TITLE','PW_AMOUNT_9089','WAGE_OFFER_FROM_9089','WAGE_OFFER_UNIT_OF_PAY_9089',
                   'JOB_INFO_WORK_CITY','JOB_INFO_WORK_STATE','JOB_INFO_WORK_POSTAL_CODE','JOB_INFO_JOB_TITLE',
                   'JOB_INFO_EDUCATION','JOB_INFO_EDUCATION_OTHER','FOREIGN_WORKER_INFO_CITY','FOREIGN_WORKER_INFO_STATE',
                   'FW_INFO_POSTAL_CODE','COUNTRY_OF_CITIZENSHIP','FW_INFO_BIRTH_COUNTRY','CLASS_OF_ADMISSION','FOREIGN_WORKER_INFO_EDUCATION','FW_INFO_EDUCATION_OTHER']]
fy16_df2.dtypes
# Out:
# CASE_NUMBER                              object
# DECISION_DATE                    datetime64[ns]
# CASE_STATUS                              object
# CASE_RECEIVED_DATE               datetime64[ns]
# EMPLOYER_NAME                            object
# EMPLOYER_CITY                            object
# EMPLOYER_STATE                           object
# EMPLOYER_POSTAL_CODE                     object
# EMPLOYER_NUM_EMPLOYEES                  float64
# AGENT_FIRM_NAME                          object
# AGENT_CITY                               object
# AGENT_STATE                              object
# PW_SOC_CODE                              object
# PW_SOC_TITLE                             object
# PW_AMOUNT_9089                          float64
# WAGE_OFFER_FROM_9089                    float64
# WAGE_OFFER_UNIT_OF_PAY_9089              object
# JOB_INFO_WORK_CITY                       object
# JOB_INFO_WORK_STATE                      object
# JOB_INFO_WORK_POSTAL_CODE                object
# JOB_INFO_JOB_TITLE                       object
# JOB_INFO_EDUCATION                       object
# JOB_INFO_EDUCATION_OTHER                 object
# FOREIGN_WORKER_INFO_CITY                 object
# FOREIGN_WORKER_INFO_STATE                object
# FW_INFO_POSTAL_CODE                      object
# COUNTRY_OF_CITIZENSHIP                   object
# FW_INFO_BIRTH_COUNTRY                    object
# CLASS_OF_ADMISSION                       object
# FOREIGN_WORKER_INFO_EDUCATION            object
# FW_INFO_EDUCATION_OTHER                  object
# dtype: object

# %%
fy16_df2.count()
# Out:
# CASE_NUMBER                      126143
# DECISION_DATE                    126143
# CASE_STATUS                      126143
# CASE_RECEIVED_DATE               126143
# EMPLOYER_NAME                    126141
# EMPLOYER_CITY                    126139
# EMPLOYER_STATE                   126131
# EMPLOYER_POSTAL_CODE             126136
# EMPLOYER_NUM_EMPLOYEES           126105
# AGENT_FIRM_NAME                  111186
# AGENT_CITY                       113483
# AGENT_STATE                      111757
# PW_SOC_CODE                      125987
# PW_SOC_TITLE                     125987
# PW_AMOUNT_9089                   126069
# WAGE_OFFER_FROM_9089             126099
# WAGE_OFFER_UNIT_OF_PAY_9089      126099
# JOB_INFO_WORK_CITY               126108
# JOB_INFO_WORK_STATE              126109
# JOB_INFO_WORK_POSTAL_CODE        126098
# JOB_INFO_JOB_TITLE               126117
# JOB_INFO_EDUCATION               126135
# JOB_INFO_EDUCATION_OTHER           4028
# FOREIGN_WORKER_INFO_CITY         126125
# FOREIGN_WORKER_INFO_STATE        115914
# FW_INFO_POSTAL_CODE              123995
# COUNTRY_OF_CITIZENSHIP           126125
# FW_INFO_BIRTH_COUNTRY            126125
# CLASS_OF_ADMISSION               117228
# FOREIGN_WORKER_INFO_EDUCATION    126122
# FW_INFO_EDUCATION_OTHER            5364
# dtype: int64

# %%
frames = [fy15_df2, fy16_df2]

result = pd.concat(frames)
result.count()
# Out:
# CASE_NUMBER                      215440
# DECISION_DATE                    215440
# CASE_STATUS                      215440
# CASE_RECEIVED_DATE               215438
# EMPLOYER_NAME                    215434
# EMPLOYER_CITY                    215432
# EMPLOYER_STATE                   215415
# EMPLOYER_POSTAL_CODE             215425
# EMPLOYER_NUM_EMPLOYEES           215355
# AGENT_FIRM_NAME                  185236
# AGENT_CITY                       189352
# AGENT_STATE                      186482
# PW_SOC_CODE                      215128
# PW_SOC_TITLE                     215128
# PW_AMOUNT_9089                   215312
# WAGE_OFFER_FROM_9089             215361
# WAGE_OFFER_UNIT_OF_PAY_9089      214194
# JOB_INFO_WORK_CITY               215378
# JOB_INFO_WORK_STATE              215379
# JOB_INFO_WORK_POSTAL_CODE        215350
# JOB_INFO_JOB_TITLE               215391
# JOB_INFO_EDUCATION               215427
# JOB_INFO_EDUCATION_OTHER           6954
# FOREIGN_WORKER_INFO_CITY         215109
# FOREIGN_WORKER_INFO_STATE        200127
# FW_INFO_POSTAL_CODE              210236
# COUNTRY_OF_CITIZENSHIP           215398
# FW_INFO_BIRTH_COUNTRY            215105
# CLASS_OF_ADMISSION               201072
# FOREIGN_WORKER_INFO_EDUCATION    215101
# FW_INFO_EDUCATION_OTHER            9316
# dtype: int64
